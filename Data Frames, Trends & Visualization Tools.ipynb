# %% [markdown]
# # Data Frames & Data Visualization Tools
#
# **1.1**
#
# ``` r
# setwd("C:/Users/15ull/OneDrive/Desktop/Labs - BIOS 20172 (Spring)/Lab2-BIOS20172_Spring2023/Lab2-BIOS20172_Spring2023")
# caffeinedata <- read.csv(file= 'caffeine_jjp.csv')
# hist(caffeinedata$Caffeine_mg_in_16_oz_coffee, xlab = 'Caffeine (MG) per 16 oz cup', main = "Amount of Caffeine per 16 oz", col = 'violetred', breaks = 2)
# ```
#
# <img src="data:image/png;base64,..." width="672" />
#
# ``` r
# caffeinedata <- read.csv(file= 'caffeine_jjp.csv')
# hist(caffeinedata$Caffeine_mg_in_16_oz_coffee, xlab = 'Caffeine (MG) per 16 oz cup', main = "Amount of Caffeine per 16 oz", col = 'violetred', breaks = 8)
# ```
#
# <img src="data:image/png;base64,..." width="672" />
# <span style="color:blue"> Since none of the values in the raw data are
# repeated more than once, the mode must be a range instead of a single
# data point. On the graph, the range that displays the highest frequency
# (7) is 150-200 mg of caffeine in a 16 oz cup. This is therefore the mode
# of the distribution. If the number of breaks is changed to 8, the range
# with the highest frequency (5) becomes 160-180 mg.</span>
#
# <span style="color:blue"> The “breaks” parameters specifies the number
# of bins that the data should be divided into when constructing a
# histogram. Increasing the number of bins may give a more detailed view
# of the data distribution so that trends can be better visualized and
# identified. If too many bins are included, the histogram may be more
# susceptible to noise and outliers. However, plotting a histogram with
# too few bins may reduce variation in the data, making it more difficult
# to identify trends. </span>
#
# **1.2**
# <span style="color:blue"> The database contains 15,880 distinct protein
# sequences and 61,882 human sequences. This information was found at the
# very bottom of the home page. </span>
#
# **1.3**
#
# ``` r
# setwd("C:/Users/15ull/OneDrive/Desktop/Labs - BIOS 20172 (Spring)/Lab2-BIOS20172_Spring2023/Lab2-BIOS20172_Spring2023")
# protein <- read.csv("protein_data.csv", header = TRUE, stringsAsFactors = FALSE)
# ncol(protein)
# ```
#
#     ## [1] 2
#
# **1.4**
#
# ``` r
# hist(protein$length, main = "Histogram of Protein Lengths", xlab = "Protein Lengths", ylab = "Frequency", breaks = 15, col = "yellow", xlim = c(0,4000))
# ```
#
# <img src="data:image/png;base64,..." width="672" />
#
# **1.5**
#
# ``` r
# setwd("C:/Users/15ull/OneDrive/Desktop/Labs - BIOS 20172 (Spring)/Lab2-BIOS20172_Spring2023/Lab2-BIOS20172_Spring2023")
# tigerdata <- read.csv('DeathsFromTigers.csv', header = TRUE, stringsAsFactors = FALSE)
# tigertable <- sort(table(tigerdata$activity), decreasing=T)
# par(mar = c(8, 5, 5, 1) + 0.1)
# barplot(tigertable, las = 2, cex.names = 0.9, ylab = "Frequency", main = "Deaths From Tigers", col = "Red")
# ```
#
# <img src="data:image/png;base64,..." width="672" />
#
# <span style="color:blue"> I know that an x axis label is included in the
# instructions document. Please note that Dr. Haddadian advised me not to
# include the x axis label for this graph and said that the individual
# labels next to each bar should be sufficient. </span>
#
# **1.6 (a)**
#
# ``` r
# setwd("C:/Users/15ull/OneDrive/Desktop/Labs - BIOS 20172 (Spring)/Lab2-BIOS20172_Spring2023/Lab2-BIOS20172_Spring2023")
# Measlesdata <- read.csv("MeaslesOutbreaks.csv", header = TRUE)
# ```
#
# **1.6 (b)**
#
# ``` r
# x1 <- Measlesdata$yearByQuarter
# y1 <- Measlesdata$confirmedCases
#
# plot(x1, y1, main = "Measles Outbreaks", xlab = "Year by Quarter", ylab = "Number of Confirmed Cases", col = "Purple")
# ```
#
# <img src="data:image/png;base64,..." width="672" />
#
# **1.6 (c)**
#
# ``` r
# x1 <- Measlesdata$yearByQuarter
# y1 <- Measlesdata$confirmedCases
#
# plot(x1, y1, type = "l", main = "Measles Outbreaks", xlab = "Year", ylab = "Number of Confirmed Cases", col = "Purple")
# ```
#
# <img src="data:image/png;base64,..." width="672" />
# <span style="color:blue"> The data is asymmetrical and there appears to
# be a peak of around 490 confirmed cases in 2009. Since there is a tail
# that extends to the left, the data is skewed to the left. Generally,
# there is an upward trend in confirmed cases from 1995 to 2010,
# indicating that the number of confirmed cases with each outbreak is
# increasing. With that said, the number of confirmed cases has yet to
# exceed 500 in a year, so measles outbreaks are still relatively rare and
# tend to impact a very small margin of the population overall. </span>
#
# **1.7**
#
# ``` r
# Gross <- 0
# for(a in tigerdata$activity){
#   if(a == "Grass/fodder"){
#     Gross <- Gross + 1
#   }
# }
#
# Forest <- 0
# for(a in tigerdata$activity){
#   if(a == "Forest products"){
#     Forest <- Forest + 1
#   }
# }
#
# Fishing <- 0
# for(a in tigerdata$activity){
#   if(a == "Fishing"){
#     Fishing <- Fishing + 1
#   }
# }
#
# Disturbing <- 0
# for(a in tigerdata$activity){
#   if(a=="Disturbing tiger kill"){
#     Disturbing <- Disturbing + 1
#   }
# }
#
# Fuel <- 0
# for(a in tigerdata$activity){
#   if(a == "Fuelwood/timber"){
#     Fuel <- Fuel + 1
#   }
# }
#
# Herding <- 0
# for(a in tigerdata$activity){
#   if(a == "Herding"){
#     Herding <- Herding + 1
#   }
# }
#
# Sleeping <- 0
# for(a in tigerdata$activity){
#   if(a == "Sleeping in house"){
#     Sleeping <- Sleeping + 1
#   }
# }
#
# Walking <- 0
# for(a in tigerdata$activity){
#   if(a == "Walking"){
#     Walking <- Walking + 1
#   }
# }
#
# Toilet <- 0
# for(a in tigerdata$activity){
#   if(a == "Toilet"){
#     Toilet <- Toilet + 1
#   }
# }
#
# Other <- Disturbing + Fuel + Herding + Sleeping + Walking + Toilet
#
# par(mar = c(3, 3, 2, 1))
#
# slices <- c(Gross, Forest, Fishing, Other)
# Activity <- c("Gross/Fodder", "Forest Products", "Fishing", "Other")
# pie(slices, Activity, main = "Deaths From Tigers")
# ```
#
# <img src="data:image/png;base64,..." width="672" />
#
# **1.8**
#
# ``` r
# setwd("C:/Users/15ull/OneDrive/Desktop/Labs - BIOS 20172 (Spring)/Lab2-BIOS20172_Spring2023/Lab2-BIOS20172_Spring2023")
# SchoolData = read.csv("SchoolData.csv")
# Results = table(SchoolData$Type, SchoolData$Decision)
#
# mosaicmat <- matrix(Results, nrow =3, ncol = 2, byrow = FALSE)
# dimnames(mosaicmat)<- list(c("Parent","Staff","Student"), c("Yes", "No"))
# Results = as.table(mosaicmat)
# mosaicplot(Results)
# ```
#
# <img src="data:image/png;base64,..." width="672" />
#
# ``` r
# mosaicplot(Results, main = "Lunch Period Election Results", xlab = "Type of Participant", ylab = "Decision", col = c("blue", "green"))
# ```
#
# <img src="data:image/png;base64,..." width="672" />
#
# **1.9 (a)**
#
# ``` r
# setwd("C:/Users/15ull/OneDrive/Desktop/Labs - BIOS 20172 (Spring)/Lab2-BIOS20172_Spring2023/Lab2-BIOS20172_Spring2023")
# countries <- read.csv("countries2005.csv", header = TRUE)
# ```
#
# **1.9 (b)**
#
# ``` r
# boxplot(countries$Population_growth ~ countries$Fertility_rate, xlab="Fertility Rate", ylab="Annual Population Growth", main="Relationship Between Fertility Rate and Annual Population Growth", col= "red")
# ```
#
# <img src="data:image/png;base64,..." width="672" />
# <span style="color:blue"> The explanatory variable is the fertility rate
# and the response variable is the population growth since population
# growth is contingent upon fertility rate. In other words, a change in
# population growth may be dependent upon the fertility rate (which could
# act as the indepndent variable in this case). As can be seen from the
# plot, there is a lot of overlap between whiskers from the y-axis
# perspective. This indicates that the spread of data is remaining
# relatively consistent as fertility rate is increasing. Or at the very
# least fertility rates are increasing faster than the population is
# growing. Additionally, the IQRs for fertility rates of 3 and 4 appear to
# be very similar if not equivalent. So, while the fertility rate is
# increasing in this case, annual population growth has not changed or has
# experienced a minimal change. There are a few outliers above and below
# the first and third quartiles. The outliers are concentrated around
# fertility rates of 1 and 2. In general, when the fertility rate is low
# (at 1 for example), the population growth is minimal (if not 0).
# Overall, both the fertility rate and population size are increasing (as
# indicated by the increasing annual population growth), albeit at
# different rates. </span>
#
# **1.9 (c)**
#
# ``` r
# boxplot(countries$Mortality_rate_adult_female_per_1000, countries$Mortality_rate_adult_male_per_1000, names = c("Female", "Male"), main = "Mortality Rates by Sex", xlab = "Sex", ylab = "Mortality Rate (per 1000)", col = c ("Red", "Blue"))
# ```
#
# <img src="data:image/png;base64,..." width="672" />
# <span style="color:blue"> The box represents the middle 50% of the data.
# The bottom and top sections of the box indicate the first and third
# quartiles, respectively, while the line inside the box represents the
# median. The whiskers extend from the top and bottom of the box to the
# minimum and maximum data points within 1.5x the IQR. The median of
# mortaility rates (per 1000) for females is lower than the median for
# males. Additionally, the middle 50% of the data is higher for males than
# females. This indicates that the mortality rate (per 1000) for males is
# higher than that for females. Though the plot for females appears to
# have a few more outliers above the third quartile, the whiskers for the
# male plot extend to a higher mortality rate. Therefore, the spread of
# data for males is more inclusive of higher mortality rates than the
# spread of data for females. All in all, males tend to have higher
# mortality rates. </span>
#
# **1.9 (d)**
#
# ``` r
# par(mar = c(12, 5, 5, 1) + 0.1)
# boxplot(countries$Life.expectancy.at.birth.female..years. ~ countries$Continent, ylab = "Female Life Expectancy At Birth (Years)", main = "Female Life Expectancy by Continent", las = 2, col = c("red"))
# ```
#
# <img src="data:image/png;base64,..." width="672" />
# <span style="color:blue"> Please note that I was unable to remove a
# label from the x axis (even though I didn’t include x lab in my code). I
# had Dr. Haddadian check my code and my plot. He is not sure why I am
# unable to remove the countries\$Continent from the x axis, but he
# approved both my plot, code, and explanation for this problem.</span>
#
# <span style="color:blue"> The box represents the middle 50% of the data.
# The bottom and top sections of the box indicate the first and third
# quartiles, respectively, while the line inside the box represents the
# median. The whiskers extend from the top and bottom of the box to the
# minimum and maximum data points within 1.5x the IQR. The IQRs are
# relatively similar for the majority of the continents, except for
# Sub-Saharan Africa. Sub-Saharan Africa has the lowest relative female
# life expectancy at birth of the continents listed. The plot for North
# America has no whiskers, indicating a smaller spread and less variation
# in data as compared to the other continents. North America also has the
# highest median of all continents, indicating that females in North
# America have the highest life expectancy (in years) at birth. </span>
#
# **1.10 (a)**
#
# ``` r
# setwd("C:/Users/15ull/OneDrive/Desktop/Labs - BIOS 20172 (Spring)/Lab2-BIOS20172_Spring2023/Lab2-BIOS20172_Spring2023")
# CoronaData <- read.csv("coronadata.csv", header = TRUE)
# ```
#
# **1.10 (b)**
#
# ``` r
# x1 <- CoronaData$Day
# y1 <- CoronaData$China
#
# plot(x1, y1, type = "l", xlab = "Day Number", ylab = "Number of New Incidences Per Day in China", main = "New Cases of COVID-19 in China")
# ```
#
# <img src="data:image/png;base64,..." width="672" />
#
# **1.10 (c)**
#
# ``` r
# x1 <- CoronaData$Day
# y1 <- CoronaData$China
#
# x2 <- CoronaData$Day
# y2 <- CoronaData$Italy
#
# plot(x1, y1, type = "l", xlab = "Day Number", ylab = "Number of New Incidences Per Day", main = "New Cases of COVID-19 in China", col = "Blue")
#
# lines(x2, y2, col= "red")
#
# legend("topright", legend = c("China", "Italy"), col = c("blue", "red"), pch = 1)
# ```
#
# <img src="data:image/png;base64,..." width="672" />
#
# **1.10 (d)** <span style="color:blue"> The plot for Italy is skewed left
# since the tail extends to the left. There is an obvious spike around day
# 45, where the number of new incidences per day reaches approximately
# 15,000 in China. Without this data point, the graph for China is
# relatively symmetrical. The peak for the Italy line graph is around 6000
# and occurs around day 80. The number of new incidences per day in Italy
# began increasing after around day 60, where the number of new incidences
# per day in China began to increase around day 20 and minimums were
# reached around day 60. This could indicate that COVID-19 affected China
# before spreading to later affect Italy. Over the span of 40 days
# (between days 20 and 60) where China is most affected and over the span
# of 40 days (from 60 to 100 days) where Italy is most affected, it
# appears that the number of new incidences per day is higher in Italy
# (other than the peak at 15,000 incidences in the China graph).</span>
#
# **2.1 (a)**
#
# ``` r
# setwd("C:/Users/15ull/OneDrive/Desktop/Labs - BIOS 20172 (Spring)/Lab2-BIOS20172_Spring2023/Lab2-BIOS20172_Spring2023")
# protein <- read.csv(file = "protein_data.csv")
# protein_DataVec <- protein$length
#
# mean(protein_DataVec)
# ```
#
#     ## [1] 545.3942
#
# ``` r
# range(protein_DataVec)
# ```
#
#     ## [1]   40 9900
#
# ``` r
# sd(protein_DataVec)
# ```
#
#     ## [1] 594.6286
#
# **2.1 (b)**
#
# ``` r
# hist(protein_DataVec, xlab = "Protein Length", ylab = "Frequency", main = "Protein Length Data", xlim = c(0,4000), col = "Orange")
# ```
#
# <img src="data:image/png;base64,..." width="672" />
#
# <span style="color:blue"> The data is not symmetrical. There is a skew
# to the right, since the tail of the graph extends to the right. It is
# unimodal, with the mode between protein lengths of 0-500 and a frequency
# of 7000. </span>
#
# **2.2 (a)**
#
# ``` r
# # Funky Sampler Code for Use in 1.2
# funkySampler <- function(dataset, size, n){
#     results <- numeric(n)
#     for(i in 1:n){
#         vectorSample <- sample(dataset, size)
#         results[i] <- mean(vectorSample)
#     }
#     return(results)
# }
#
# par(mfrow=c(2,2))
#
# vectorOfInterest <- c(protein_DataVec)
# ourSampleSize <- 9
# ournTrials <- 83
#
# dist <- funkySampler(vectorOfInterest, ourSampleSize, ournTrials)
# hist(dist, xlab = "Protein Length", main = "Distribution of Protein Samples (Size = 9)", col = "Red")
#
# mean(dist)
# ```
#
#     ## [1] 559.1526
#
# ``` r
# ourSampleSize2 <- 19
# ournTrials2 <- 83
#
# dist2 <- funkySampler(vectorOfInterest, ourSampleSize, ournTrials)
# hist(dist2, xlab = "Protein Length", main = "Distribution of Protein Samples (Size = 19)", col = "Blue")
#
# mean(dist2)
# ```
#
#     ## [1] 553.8541
#
# ``` r
# ourSampleSize3 <- 199
# ournTrials3 <- 83
#
# dist3 <- funkySampler(vectorOfInterest, ourSampleSize, ournTrials)
# hist(dist3, xlab = "Protein Length", main = "Distribution of Protein Samples (Size = 199)", col = "Green")
#
# mean(dist3)
# ```
#
#     ## [1] 569.573
#
# ``` r
# ourSampleSize4 <- 1999
# ournTrials4 <- 83
#
# dist4 <- funkySampler(vectorOfInterest, ourSampleSize, ournTrials)
# hist(dist4, xlab = "Protein Length", main = "Distribution of Protein Samples (Size = 1999)", col = "Yellow")
# ```
#
# <img src="data:image/png;base64,..." width="672" />
#
# ``` r
# mean(dist4)
# ```
#
#     ## [1] 540.5515
#
# **2.2 (b)**
#
# <span style="color:blue"> ourSampleSize = 9 </span>
#
# <span style="color:blue"> The data is asymmetrical and skewed to the
# left. </span>
#
# <span style="color:blue"> ourSampleSize = 19 </span>
#
# <span style="color:blue"> The data is asymmetrical and there is a slight
# skew to the left. </span>
#
# <span style="color:blue"> ourSampleSize = 199 </span>
#
# <span style="color:blue"> The data is becoming increasingly symmetric
# and the skew to the left is becoming less apparent. </span>
#
# <span style="color:blue"> ourSampleSize = 1999 </span>
#
# <span style="color:blue"> As the sample size increases, the distribution
# tends to become more normal and less skewed. This is because random
# variation in sample means tends to almost “cancel out” as sample size
# increases, resulting in a more consistent and symmetric distribution of
# sample means.</span>
#
# <span style="color:blue"> No, every sample does not return the same
# value of the mean. As the sample size increases, the mean (in general)
# tends to approach the true population mean, assuming that the sampling
# process is random and unbiased. The value of the mean may vary depending
# on the distribution of the data in the sample. For example, if the data
# is highly skewed or contains many outliers, means may be influenced to
# varying degrees by these extreme values. Therefore, the mean of each
# sample may differ, depending on the values in the sample and
# distribution of the data. </span>
#
# **2.2 (c)** <span style="color:blue"> As the sample size increases, the
# distribution of the results tends to become more normal, with a smaller
# variance and more accurate estimation of the true population parameter.
# As sample size increases, the standard error of the mean may decrease,
# indicating that the sample is a more precise estimate of the population.
# </span>
#
# **2.2 (d)** <span style="color:blue"> The sample means overall tend to
# be less than the population mean. In addition, smaller sample sizes tend
# to have a larger difference between the sample mean and population mean,
# whereas larger sample sizes tend to have a smaller difference. Any
# discrepancies may be the result of sampling error, which cannot be
# removed and decribes the difference between an estimate and the
# population parameter being estimated. They may also be the result of
# bias, which is a systematic error describing the difference between an
# estimate and true population parameter and affecting every unit in the
# sample. </span>
#
# **2.3**
#
# ``` r
# funkySampler <- function(dataset, size, n){
#     results <- numeric(n)
#     for(i in 1:n){
#         vectorSample <- sample(dataset, size)
#         results[i] <- mean(vectorSample)
#     }
#     return(results)
# }
#
# par(mfrow=c(2,2))
#
# vectorOfInterest <- c(protein_DataVec)
# ourSampleSize <- 8
# ournTrials <- 50
#
# dist <- funkySampler(vectorOfInterest, ourSampleSize, ournTrials)
# hist(dist, xlab = "Protein Length", main = "Distribution of Protein Samples", col = "Blue")
#
# mean(dist)
# ```
#
#     ## [1] 568.3575
#
# ``` r
# ourSampleSize2 <- 8
# ournTrials2 <- 100
#
# dist2 <- funkySampler(vectorOfInterest, ourSampleSize, ournTrials)
# hist(dist2, xlab = "Protein Length", main = "Distribution of Protein Samples", col = "Blue")
#
# mean(dist2)
# ```
#
#     ## [1] 622.7925
#
# ``` r
# ourSampleSize3 <- 8
# ournTrials3 <- 500
#
# dist3 <- funkySampler(vectorOfInterest, ourSampleSize, ournTrials)
# hist(dist3, xlab = "Protein Length", main = "Distribution of Protein Samples", col = "Blue")
#
# mean(dist3)
# ```
#
#     ## [1] 530.37
#
# ``` r
# ourSampleSize4 <- 8
# ournTrials4 <- 1000
#
# dist4 <- funkySampler(vectorOfInterest, ourSampleSize, ournTrials)
# hist(dist4, xlab = "Protein Length", main = "Distribution of Protein Samples", col = "Blue")
# ```
#
# <img src="data:image/png;base64,..." width="672" />
#
# ``` r
# mean(dist4)
# ```
#
#     ## [1] 523.565
#
# <span style="color:blue"> As the number of trials increases while
# keeping the sample size constant, the sample mean becomes a better
# estimator of the population mean. In other words, as more trials are
# taken, more data is collected and the impact of random variation in any
# single sample is reduced. As a result, if there are more trials, there
# is a higher likelihood that sample means will average out to be
# concentrated closer to the true population mean. In addition, (as
# Dr. Haddadian mentioned during lab) error is determined from sample
# size, which is constant in all four histograms. </span>
#
# ``` r
# # If you haven't installed seqinr yet then uncomment the line below this
# #install.packages('seqinr')
# setwd("C:/Users/15ull/OneDrive/Desktop/Labs - BIOS 20172 (Spring)/Lab2-BIOS20172_Spring2023/Lab2-BIOS20172_Spring2023")
# library('seqinr')
# ```
#
#     ## Warning: package 'seqinr' was built under R version 4.2.3
#
# ``` r
# Zika <- read.fasta(file = 'Zika.fasta')
# Zika_vec <- as.vector(Zika[[1]])
# ```
#
# **2.4 (a)**
#
# ``` r
# GC_Content<-function(x){
#
# length <- 0
# for(a in x){
#   length <- length + 1
# }
# num_c <- 0
# for(a in x){
#   if(a == "c"){
#     num_c <- num_c + 1
#   }
# }
#
# num_g <- 0
# for(a in x){
#   if(a == "g"){
#     num_g <- num_g + 1
#   }
# }
#
# my_gC <- ((num_g + num_c)/length(x)) * 100
# return(my_gC)
# }
# findGC <- function(dataset, size, n){
#     results <- numeric(n)
#     for(i in 1:n){
#         vectorSample <- sample(dataset, size)
#         results[i] <- GC_Content(vectorSample)
#     }
#     return(results)
# }
# ```
#
# **2.4 (b)**
#
# ``` r
# GC_Content<-function(x){
#
# length <- 0
# for(a in x){
#   length <- length + 1
# }
# num_c <- 0
# for(a in x){
#   if(a == "c"){
#     num_c <- num_c + 1
#   }
# }
#
# num_g <- 0
# for(a in x){
#   if(a == "g"){
#     num_g <- num_g + 1
#   }
# }
#
# my_gC <- ((num_g + num_c)/length(x)) * 100
# return(my_gC)
# }
# findGC <- function(dataset, size, n){
#     results <- numeric(n)
#     for(i in 1:n){
#         vectorSample <- sample(dataset, size, replace = TRUE)
#         results[i] <- GC_Content(vectorSample)
#     }
#     return(results)
# }
#
# x1 <- findGC(Zika_vec, 18, 125)
# x2 <- findGC(Zika_vec, 180, 125)
# x3 <- findGC(Zika_vec, 1800, 125)
# x4 <- findGC(Zika_vec, 18000, 125)
#
# par(mfrow=c(2,2))
#
# hist(x1, xlab = "GC Content", main = "Sample Size 18", col = "Green")
# mean(x1)
# ```
#
#     ## [1] 47.73333
#
# ``` r
# hist(x2, xlab = "GC Content", main = "Sample Size 180", col = "Green")
# mean(x2)
# ```
#
#     ## [1] 50.91556
#
# ``` r
# hist(x3, xlab = "GC Content", main = "Sample Size 1800", col = "Green")
# mean(x3)
# ```
#
#     ## [1] 50.86178
#
# ``` r
# hist(x4, xlab = "GC Content", main = "Sample Size 18000", col = "Green")
# ```
#
# <img src="data:image/png;base64,..." width="672" />
#
# ``` r
# mean(x4)
# ```
#
#     ## [1] 50.95258
#
# <span style="color:blue"> As the sample size increases, the distribution
# of the results becomes more symmetrical. When the sample size is 18,
# there appears to be a slight left skew. When the sample size is
# increased to 180, there appears to be a slight right skew. However, at
# sample sizes of 1800 and 18000, the data appears to be more symmetrical
# and trends appear more visible (for instance in the graphs generated in
# my console, the last plot is unimodal with a clearly identifiable peak).
# In other words, the distribution tends to become more accurate as the
# sample size is increased. Additionally, it may be possible to obtain
# more precise measurements of central tendency with larger sample sizes.
# </span>
#
# **2.4 (c)** <span style="color:blue"> In the last lab, the GC Content of
# Zika DNA Sequence calculated to be 50.93571. As sample sizes increase,
# means tend to approach this value (although different means are
# generated each time the code is run). </span>
